# %% [markdown]
# 1. Best Chip Processor
# 2. Suggested ROM
# 3. Enhancive Display
# 4. Highest Rating
# 5. Price (At Least)
# ## RESULT : Model Name

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

df = pd.read_csv(r'C:\Users\Lenovo\Downloads\iPhone\iPhonesCleaned.csv')
df
# Out:
#                                          Model Name  Rating  ROM  \
# 0                   APPLE iPhone 11 (Black, 128 GB)     4.6  128
# 1                   APPLE iPhone 11 (White, 128 GB)     4.6  128
# 2                APPLE iPhone 13 (Midnight, 128 GB)     4.7  128
# 3                   APPLE iPhone 13 (Green, 128 GB)     4.7  128
# 4                    APPLE iPhone 11 (Black, 64 GB)     4.6   64
# ..                                              ...     ...  ...
# 344            APPLE iPhone 12 mini (Purple, 64 GB)     4.5   64
# 345        APPLE iPhone 12 Pro Max (Silver, 256 GB)     4.5  256
# 346         APPLE iPhone 11 Pro (Space Grey, 64 GB)     4.6   64
# 347  APPLE iPhone 12 Pro Max (Pacific Blue, 128 GB)     4.5  128
# 348        APPLE iPhone 6s Plus (Space Grey, 16 GB)     4.4   16
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           15.49            A13           200360.0            11406.0
# ...

# %% [markdown]
# # 1. Univariate analysis

# %%
df.sort_values(by='ROM',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                          Model Name  Rating  ROM  \
# 0    APPLE iPhone 12 Pro Max (Pacific Blue, 512 GB)     4.5  512
# 1              APPLE iPhone 13 Pro (Silver, 512 GB)     4.7  512
# 2           APPLE iPhone 14 Plus (Midnight, 512 GB)     4.6  512
# 3                    APPLE iPhone 13 (Pink, 512 GB)     4.7  512
# 4               APPLE iPhone 13 (Starlight, 512 GB)     4.7  512
# ..                                              ...     ...  ...
# 344              APPLE iPhone 6s Plus (Gold, 16 GB)     4.4   16
# 345                   APPLE iPhone 6s (Gold, 16 GB)     4.5   16
# 346         APPLE iPhone 6s Plus (Rose Gold, 16 GB)     4.4   16
# 347             APPLE iPhone 6s (Space Grey, 16 GB)     4.5   16
# 348        APPLE iPhone 6s Plus (Space Grey, 16 GB)     4.4   16
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           17.02            A14             1270.0              103.0
# ...

# %%
sns.countplot(x='ROM',data=df)
plt.show()

# %%
colors = sns.color_palette('colorblind')[0:10]
df["ROM"].value_counts().plot.pie(autopct="%.1f%%",colors=colors,fontsize=6)
plt.show()

# %%
colors = sns.color_palette('colorblind')[0:10]
sns.displot(df["ROM"],kde=True,bins = [8,16,64,128,512])
plt.title('Histogram of ROM (Storage)')
plt.show()

# %%
df.sort_values(by='Display (cm)',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                          Model Name  Rating  ROM  \
# 0    APPLE iPhone 12 Pro Max (Pacific Blue, 512 GB)     4.5  512
# 1            APPLE iPhone 12 Pro Max (Gold, 512 GB)     4.5  512
# 2     APPLE iPhone 14 Pro Max (Deep Purple, 256 GB)     4.6  256
# 3            APPLE iPhone 13 Pro Max (Gold, 256 GB)     4.6  256
# 4        APPLE iPhone 12 Pro Max (Graphite, 256 GB)     4.5  256
# ..                                              ...     ...  ...
# 344                 APPLE iPhone SE (Black, 256 GB)     4.5  256
# 345                  APPLE iPhone SE (White, 64 GB)     4.5   64
# 346                  APPLE iPhone SE (Black, 64 GB)     4.5   64
# 347                 APPLE iPhone 7 (Silver, 256 GB)     4.5  256
# 348              APPLE iPhone 7 (Jet Black, 256 GB)     4.5  256
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           17.02            A14             1270.0              103.0
# ...

# %%
df['Display (cm)'].value_counts()
# Out:
# 15.49    124
# 11.94     71
# 17.02     54
# 13.72     30
# 13.97     26
# 16.51     19
# 14.73     14
# 13.94     10
# 15.50      1
# Name: Display (cm), dtype: int64

# %%
sns.countplot(x='Display (cm)',data=df)
plt.show()

# %%
colors = sns.color_palette('colorblind')[0:10]
df["Display (cm)"].value_counts().plot.pie(autopct="%.1f%%",colors=colors,fontsize=6)
plt.show()

# %%
sns.violinplot(df['Display (cm)'],kde=True)
plt.title('Display (cm)')
plt.show()

# %%
df.sort_values(by='Chip Processor',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                         Model Name  Rating  ROM  Display (cm)  \
# 0        APPLE iPhone 14 Pro (Deep Purple, 512 GB)     4.6  512         15.49
# 1    APPLE iPhone 14 Pro Max (Space Black, 256 GB)     4.6  256         17.02
# 2    APPLE iPhone 14 Pro Max (Deep Purple, 512 GB)     4.6  512         17.02
# 3           APPLE iPhone 14 Pro Max (Gold, 512 GB)     4.6  512         17.02
# 4             APPLE iPhone 14 Pro (Silver, 512 GB)     4.6  512         15.49
# ..                                             ...     ...  ...           ...
# 344        APPLE iPhone 8 Plus (Space Grey, 64 GB)     4.6   64         13.97
# 345  APPLE iPhone 8 Plus (PRODUCT)RED (Red, 64 GB)     4.6   64         13.97
# 346            APPLE iPhone 8 (Space Grey, 256 GB)     4.5  256         11.94
# 347             APPLE iPhone 8 Plus (Gold, 256 GB)     4.6  256         13.97
# 348             APPLE iPhone 8 (Space Grey, 64 GB)     4.5   64         11.94
#
# ...

# %%
df['Chip Processor'].value_counts()
# Out:
# A15    178
# A14     52
# A13     44
# A12     43
# A16     23
# A11      9
# Name: Chip Processor, dtype: int64

# %%
sns.countplot(x='Chip Processor',data=df)
plt.show()

# %%
colors = sns.color_palette('colorblind')[0:10]
df["Chip Processor"].value_counts().plot.pie(autopct="%.1f%%",colors=colors,fontsize=6)
plt.show()

# %%
sns.displot(df['Chip Processor'],kde=True)
plt.show()

# %%
sns.histplot(df['Price(₹)'], bins=20, color='g')  
plt.title('Histogram of Price(₹)')
plt.show()

# %%
sns.boxplot(df['Price(₹)'],color='g')
plt.show()

# %%
df['Price(₹)'].mean()
# Out:
# 78006.28080229227

# %% [markdown]
# # 2. Bivariate analysis

# %%
df = pd.read_csv(r'C:\Users\Lenovo\Downloads\iPhone\iPhonesCleaned.csv')
df
# Out:
#                                          Model Name  Rating  ROM  \
# 0                   APPLE iPhone 11 (Black, 128 GB)     4.6  128
# 1                   APPLE iPhone 11 (White, 128 GB)     4.6  128
# 2                APPLE iPhone 13 (Midnight, 128 GB)     4.7  128
# 3                   APPLE iPhone 13 (Green, 128 GB)     4.7  128
# 4                    APPLE iPhone 11 (Black, 64 GB)     4.6   64
# ..                                              ...     ...  ...
# 344            APPLE iPhone 12 mini (Purple, 64 GB)     4.5   64
# 345        APPLE iPhone 12 Pro Max (Silver, 256 GB)     4.5  256
# 346         APPLE iPhone 11 Pro (Space Grey, 64 GB)     4.6   64
# 347  APPLE iPhone 12 Pro Max (Pacific Blue, 128 GB)     4.5  128
# 348        APPLE iPhone 6s Plus (Space Grey, 16 GB)     4.4   16
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           15.49            A13           200360.0            11406.0
# ...

# %% [markdown]
# ### Numerical vs  Numerical

# %%
df.sort_values(by='ROM',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                          Model Name  Rating  ROM  \
# 0    APPLE iPhone 12 Pro Max (Pacific Blue, 512 GB)     4.5  512
# 1              APPLE iPhone 13 Pro (Silver, 512 GB)     4.7  512
# 2           APPLE iPhone 14 Plus (Midnight, 512 GB)     4.6  512
# 3                    APPLE iPhone 13 (Pink, 512 GB)     4.7  512
# 4               APPLE iPhone 13 (Starlight, 512 GB)     4.7  512
# ..                                              ...     ...  ...
# 344              APPLE iPhone 6s Plus (Gold, 16 GB)     4.4   16
# 345                   APPLE iPhone 6s (Gold, 16 GB)     4.5   16
# 346         APPLE iPhone 6s Plus (Rose Gold, 16 GB)     4.4   16
# 347             APPLE iPhone 6s (Space Grey, 16 GB)     4.5   16
# 348        APPLE iPhone 6s Plus (Space Grey, 16 GB)     4.4   16
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           17.02            A14             1270.0              103.0
# ...

# %%
sns.regplot(x=df['ROM'],y=df['Price(₹)'])
plt.show()

# %%
sns.pairplot(data=df,vars=['Display (cm)','Price(₹)'])
plt.show()

# %%
df.sort_values(by='Rating',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                           Model Name  Rating  ROM  \
# 0        APPLE iPhone 7 Plus (PRODUCT) (Red, 256 GB)     5.0  256
# 1             APPLE iPhone 13 Pro (Graphite, 256 GB)     4.7  256
# 2             APPLE iPhone 11 Pro Max (Gold, 256 GB)     4.7  256
# 3          APPLE iPhone 13 Pro (Sierra Blue, 128 GB)     4.7  128
# 4    APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)     4.7   64
# ..                                               ...     ...  ...
# 344               APPLE iPhone 6 (Space Grey, 64 GB)     4.4   64
# 345                   APPLE iPhone 6 (Silver, 64 GB)     4.4   64
# 346                     APPLE iPhone 6 (Gold, 64 GB)     4.4   64
# 347               APPLE iPhone 6s Plus (Gold, 64 GB)     4.4   64
# 348         APPLE iPhone 6s Plus (Space Grey, 16 GB)     4.4   16
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           13.97            A15       53321.661111        4900.789326
# ...

# %%
sns.barplot(x='Rating',y='Price(₹)',data=df)
plt.show()

# %% [markdown]
# ### Numerical vs Categorical

# %%
df.sort_values(by='ROM',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                      Model Name  Rating  ROM  Display (cm)  \
# 0          APPLE iPhone 12 Pro (Silver, 512 GB)     4.5  512         15.49
# 1          APPLE iPhone 14 Pro (Silver, 512 GB)     4.6  512         15.49
# 2    APPLE iPhone 12 Pro Max (Graphite, 512 GB)     4.5  512         17.02
# 3    APPLE iPhone 13 Pro (Alpine Green, 512 GB)     4.7  512         15.49
# 4            APPLE iPhone 13 (Midnight, 512 GB)     4.7  512         15.49
# ..                                          ...     ...  ...           ...
# 344             APPLE iPhone 6s (Silver, 16 GB)     4.5   16         11.94
# 345        APPLE iPhone 6s Plus (Silver, 16 GB)     4.4   16         13.97
# 346          APPLE iPhone 6s Plus (Gold, 16 GB)     4.4   16         13.97
# 347     APPLE iPhone 6s Plus (Rose Gold, 16 GB)     4.4   16         13.97
# 348    APPLE iPhone 6s Plus (Space Grey, 16 GB)     4.4   16         13.97
#
#     Chip Processor  Number of Ratings  Number of Reviews  Price(₹)
# ...

# %%
sns.lineplot(x='ROM',y='Chip Processor',data=df)
plt.show()

# %%
df.sort_values(by='Chip Processor',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                         Model Name  Rating  ROM  Display (cm)  \
# 0        APPLE iPhone 14 Pro (Space Black, 256 GB)     4.6  256         15.49
# 1    APPLE iPhone 14 Pro Max (Deep Purple, 256 GB)     4.6  256         17.02
# 2             APPLE iPhone 14 Pro (Silver, 512 GB)     4.6  512         15.49
# 3        APPLE iPhone 14 Pro (Deep Purple, 256 GB)     4.6  256         15.49
# 4    APPLE iPhone 14 Pro Max (Space Black, 512 GB)     4.6  512         17.02
# ..                                             ...     ...  ...           ...
# 344                  APPLE iPhone 8 (Gold, 256 GB)     4.5  256         11.94
# 345            APPLE iPhone 8 (Space Grey, 256 GB)     4.5  256         11.94
# 346                APPLE iPhone 8 (Silver, 256 GB)     4.5  256         11.94
# 347             APPLE iPhone 8 Plus (Gold, 256 GB)     4.6  256         13.97
# 348      APPLE iPhone 8 (PRODUCT)RED (Red, 256 GB)     4.7  256         11.94
#
# ...

# %%
sns.boxplot(x='Chip Processor',y='Display (cm)',data=df)
plt.show()

# %%
df.sort_values(by='Price(₹)',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                             Model Name  Rating  ROM  \
# 0        APPLE iPhone 14 Pro Max (Space Black, 512 GB)     4.6  512
# 1               APPLE iPhone 14 Pro Max (Gold, 512 GB)     4.6  512
# 2             APPLE iPhone 14 Pro Max (Silver, 512 GB)     4.6  512
# 3        APPLE iPhone 14 Pro Max (Deep Purple, 512 GB)     4.6  512
# 4     APPLE iPhone 11 Pro Max (Midnight Green, 512 GB)     4.7  512
# ..                                                 ...     ...  ...
# 344  Apple iPhone SE (Red, 64 GB) (Includes EarPods...     4.5   64
# 345                     APPLE iPhone SE (Black, 64 GB)     4.5   64
# 346  Apple iPhone SE (Black, 64 GB) (Includes EarPo...     4.5   64
# 347                     APPLE iPhone SE (White, 64 GB)     4.5   64
# 348                       APPLE iPhone 6 (Gold, 32 GB)     4.4   32
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           17.02            A16             1985.0              145.0
# ...

# %%
sns.barplot(x='Price(₹)',y='Chip Processor',data=df,orient="h")
plt.xticks(rotation = 90)
plt.show()

# %%
df.sort_values(by='Chip Processor',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                         Model Name  Rating  ROM  Display (cm)  \
# 0    APPLE iPhone 14 Pro Max (Space Black, 512 GB)     4.6  512         17.02
# 1    APPLE iPhone 14 Pro Max (Space Black, 128 GB)     4.6  128         17.02
# 2    APPLE iPhone 14 Pro Max (Space Black, 256 GB)     4.6  256         17.02
# 3    APPLE iPhone 14 Pro Max (Deep Purple, 256 GB)     4.6  256         17.02
# 4        APPLE iPhone 14 Pro (Space Black, 256 GB)     4.6  256         15.49
# ..                                             ...     ...  ...           ...
# 344             APPLE iPhone 8 (Space Grey, 64 GB)     4.5   64         11.94
# 345                APPLE iPhone 8 (Silver, 256 GB)     4.5  256         11.94
# 346            APPLE iPhone 8 (Space Grey, 256 GB)     4.5  256         11.94
# 347      APPLE iPhone 8 (PRODUCT)RED (Red, 256 GB)     4.7  256         11.94
# 348       APPLE iPhone 8 (PRODUCT)RED (Red, 64 GB)     4.7   64         11.94
#
# ...

# %%
sns.barplot(x='Chip Processor',y='Rating',data=df)
plt.show()

# %% [markdown]
# ### Categorical vs Categorical

# %%
crosstab = pd.crosstab(df['Chip Processor'],df['Model Name'])
crosstab.plot(kind='bar',stacked=True,legend=None)
plt.show()

# %% [markdown]
# # 3. MultiVariate analysis

# %%
df = pd.read_csv(r'C:\Users\Lenovo\Downloads\iPhone\iPhonesCleaned.csv')
df
# Out:
#                                          Model Name  Rating  ROM  \
# 0                   APPLE iPhone 11 (Black, 128 GB)     4.6  128
# 1                   APPLE iPhone 11 (White, 128 GB)     4.6  128
# 2                APPLE iPhone 13 (Midnight, 128 GB)     4.7  128
# 3                   APPLE iPhone 13 (Green, 128 GB)     4.7  128
# 4                    APPLE iPhone 11 (Black, 64 GB)     4.6   64
# ..                                              ...     ...  ...
# 344            APPLE iPhone 12 mini (Purple, 64 GB)     4.5   64
# 345        APPLE iPhone 12 Pro Max (Silver, 256 GB)     4.5  256
# 346         APPLE iPhone 11 Pro (Space Grey, 64 GB)     4.6   64
# 347  APPLE iPhone 12 Pro Max (Pacific Blue, 128 GB)     4.5  128
# 348        APPLE iPhone 6s Plus (Space Grey, 16 GB)     4.4   16
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           15.49            A13           200360.0            11406.0
# ...

# %%
df.sort_values(by='ROM',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                          Model Name  Rating  ROM  \
# 0    APPLE iPhone 12 Pro Max (Pacific Blue, 512 GB)     4.5  512
# 1              APPLE iPhone 13 Pro (Silver, 512 GB)     4.7  512
# 2           APPLE iPhone 14 Plus (Midnight, 512 GB)     4.6  512
# 3                    APPLE iPhone 13 (Pink, 512 GB)     4.7  512
# 4               APPLE iPhone 13 (Starlight, 512 GB)     4.7  512
# ..                                              ...     ...  ...
# 344              APPLE iPhone 6s Plus (Gold, 16 GB)     4.4   16
# 345                   APPLE iPhone 6s (Gold, 16 GB)     4.5   16
# 346         APPLE iPhone 6s Plus (Rose Gold, 16 GB)     4.4   16
# 347             APPLE iPhone 6s (Space Grey, 16 GB)     4.5   16
# 348        APPLE iPhone 6s Plus (Space Grey, 16 GB)     4.4   16
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           17.02            A14             1270.0              103.0
# ...

# %%
sns.lineplot(x='ROM',y='Display (cm)',hue='Chip Processor',data = df)
plt.show()

# %%
df.sort_values(by='Rating',ascending=False,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                           Model Name  Rating  ROM  \
# 0        APPLE iPhone 7 Plus (PRODUCT) (Red, 256 GB)     5.0  256
# 1             APPLE iPhone 13 Pro (Graphite, 256 GB)     4.7  256
# 2             APPLE iPhone 11 Pro Max (Gold, 256 GB)     4.7  256
# 3          APPLE iPhone 13 Pro (Sierra Blue, 128 GB)     4.7  128
# 4    APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)     4.7   64
# ..                                               ...     ...  ...
# 344               APPLE iPhone 6 (Space Grey, 64 GB)     4.4   64
# 345                   APPLE iPhone 6 (Silver, 64 GB)     4.4   64
# 346                     APPLE iPhone 6 (Gold, 64 GB)     4.4   64
# 347               APPLE iPhone 6s Plus (Gold, 64 GB)     4.4   64
# 348         APPLE iPhone 6s Plus (Space Grey, 16 GB)     4.4   16
#
#      Display (cm) Chip Processor  Number of Ratings  Number of Reviews  \
# 0           13.97            A15       53321.661111        4900.789326
# ...

# %%
sns.lineplot(x='Number of Ratings',y='Number of Reviews',hue='Rating',data=df)
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Number of Ratings'], df['Number of Reviews'], df['Rating'],marker='o')
plt.title('Rating in accordance with number of ratings and reviews')
ax.set_xlabel('Number of Ratings')
ax.set_ylabel('Number of Reviews')
ax.set_zlabel('Rating')
plt.show()

# %% [markdown]
# # CORRELATION

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10824\2298098936.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
expected_df = df[(df['Chip Processor']=='A15')&
                 (df['ROM']>=256)&
                 (df['Display (cm)']>=15.49)&
                 (df['Rating']>=4.5)]

# %%
expected_df['Price(₹)'].min()
# Out:
# 65999

# %%
expected_df['Price(₹)'].max()
# Out:
# 139900

# %%
expected_df['Price(₹)'].mean()
# Out:
# 103544.63636363637

# %% [markdown]
# # Results Summary:
#
# 1. **Optimal Chip Processor - A15:** The A15 processor exhibits extensive availability across various phone models, making it a compelling choice.
#
# 2. **Recommended ROM - 256GB:** Despite having two more options in the 128GB category, the preference leans towards 256GB of ROM (Storage). This choice anticipates the evolving technology landscape, necessitating ample space for software installations and updates.
#
# 3. **Immersive Display - 15.49 cm:** The market offers a plethora of smartphone models with a 15.49 cm display size. This variety provides consumers with a wide range of choices to explore.
#
# 4. **Top Ratings - 4.5 and Above:** Our selection criteria prioritize iPhones that meet all the aforementioned conditions while also boasting a minimum rating of 4.5 or higher.
#
# 5. **Budget-Friendly Pricing - Starting at ₹65,999/-:** Remarkably, you can discover iPhones that meet all the specified criteria, and they start at a competitive price point of ₹65,999/-. This ensures an attractive blend of performance and affordability.
#
# These refined observations guide us towards making an informed choice when selecting the ideal iPhone model that aligns with our preferences and requirements.

# %%
output_df = expected_df[(expected_df['Price(₹)']==65999)]

# %%
output_df[['Model Name']]
# Out:
#                                 Model Name
# 21  APPLE iPhone 13 ((PRODUCT)RED, 256 GB)
# 22      APPLE iPhone 13 (Midnight, 256 GB)
# 25          APPLE iPhone 13 (Pink, 256 GB)
# 28     APPLE iPhone 13 (Starlight, 256 GB)
# 30          APPLE iPhone 13 (Blue, 256 GB)
# 34         APPLE iPhone 13 (Green, 256 GB)

# %% [markdown]
# ![Apple iPhone GIF](iPhone.gif)

# %% [markdown]
# # CONCLUSION
#
# After conducting an analysis of the data scraped from Flipkart, it is evident that the iPhone 13 stands out as the best choice among the available options. Here's a breakdown of the key features and why the iPhone 13 satisfies them:
#
# 1. **Model Name**: The iPhone 13, as the model in question, is a current-generation device, ensuring you get the latest technology and features available.
#
# 2. **Rating**: The iPhone 13 has received consistently high ratings, indicating a high level of customer satisfaction. This suggests that users are generally pleased with its performance and features.
#
# 3. **ROM (Storage)**: While the specific storage capacity may vary among models, the iPhone 13 offers a range of storage options to suit your needs, from 128GB to 512GB. This ensures ample space for your apps, media, and files.
#
# 4. **Display Size (cm)**: The iPhone 13 features a quality display with various sizes, catering to different preferences. Whether you prefer a compact device or a larger screen for media consumption, the iPhone 13 has you covered.
#
# 5. **Chip Processor**: The iPhone 13 is powered by Apple's latest A15 Bionic chip, known for its exceptional performance, efficiency, and advanced AI capabilities. It ensures smooth multitasking, fast app launches, and excellent gaming experiences.
#
# 6. **Number of Ratings and Reviews**: The iPhone 13 has received a significant number of ratings and reviews, indicating its popularity and a large user base. This suggests that it is a widely trusted and used device.
#
# 7. **Price**: While the iPhone 13 may not be the cheapest option on the market, its price is justified by the premium features, build quality, and performance it offers. It provides value for money considering the overall package.
#
# In conclusion, the iPhone 13 excels in all the key features you've scraped from Flipkart. It boasts high ratings, ample storage options, a versatile display, a powerful processor, a substantial user base, and a price point that reflects its premium quality. Therefore, based on this analysis, the iPhone 13 is indeed the best choice for those looking for a top-tier smartphone on Flipkart. However, it's essential to consider your personal preferences and budget before making a final decision.
